# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.2

# %%
# !git clone https://github.com/cds0987/MedAI-Project.git
# %cd MedAI-Project/
# !pip -q install -r requirements.txt
# !pip install Flask
# Out:
# Cloning into 'MedAI-Project'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 135 (delta 1), reused 5 (delta 1), pack-reused 127 (from 2)
# Receiving objects: 100% (135/135), 166.47 MiB | 44.42 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/MedAI-Project
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 92.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: Flask in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from Flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->Flask) (3.0.2)

# %%
from google.colab import userdata
from flask import Flask
from Webbuild.route import routebp
from Webbuild.feature import featurebp
app = Flask(__name__)
app.config['SECRET_KEY'] = '1537'
app.config.from_pyfile('config.py')
# Register blueprints
app.register_blueprint(routebp, url_prefix='/')
app.register_blueprint(featurebp, url_prefix='/feature')
# Out:
# /content/MedAI-Project/AImodels/classification.py:151: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(os.path.abspath('AImodels/Weight/BrainTumor classification/Modelefficientnet_b0_BrainTumorClassification.pt'))
# /content/MedAI-Project/AImodels/classification.py:80: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(os.path.abspath('AImodels/Weight/BrainTumor classification/Modelefficientnet_b0_BrainTumorClassification.pt')) # Load the model architecture
# /content/MedAI-Project/AImodels/classification.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(os.path.abspath('AImodels/Weight/Cataract/Cataract_Model_efficientnet_b0_best.pt'), map_location=self.device)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/70.0k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/52.9M [00:00<?, ?B/s]
# /content/MedAI-Project/AImodels/detection.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path, map_location=self.device)
# preprocessor_config.json:   0%|          | 0.00/171 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/6.88k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/15.0M [00:00<?, ?B/s]
# /content/MedAI-Project/AImodels/segmantation.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict=torch.load(state_dict_path)
# preprocessor_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]

# %%
from pyngrok import ngrok, conf
from flask import Flask
from google.colab import userdata
import os
import json


# Generate the public URL
conf.get_default().auth_token = userdata.get('ngrock')
public_url = ngrok.connect(5000).public_url
print('public_url', public_url)

if __name__ == '__main__':
    app.run(debug=False, host='0.0.0.0', use_reloader=False)
# Out:
# public_url https://5aa1-34-13-157-78.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 12:59:53] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 12:59:55] "GET /static/index.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 12:59:56] "GET /static/Images/offical.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 12:59:56] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 12:59:59] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:01] "GET /static/mainpage.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:01] "GET /static/Images/usermain.jfif HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:03] "GET /brain_class HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:04] "GET /static/moleculeimage.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:05] "GET /static/Images/describer.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:13] "POST /feature/describe_image HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:14] "GET /static/result.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:14] "GET /static/uploads/BrainTumor_classification.jpeg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:17] "GET /brain_class HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:19] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:20] "GET /static/mainpage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:21] "GET /cataract HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:23] "GET /static/moleculeimage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:31] "POST /feature/describe_image HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:32] "GET /static/uploads/NL_001.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:32] "GET /static/result.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:37] "GET /cataract HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:39] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:41] "GET /static/mainpage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:42] "GET /static/Images/usermain.jfif HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:42] "GET /oral HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:44] "GET /static/moleculeimage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:53] "POST /feature/describe_image HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:53] "GET /static/result.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:53] "GET /static/uploads/oral.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:56] "GET /oral HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:59] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:00:59] "GET /static/mainpage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:01] "GET /brain_detect HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:02] "GET /static/moleculeimage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:08] "POST /feature/describe_image HTTP/1.1" 302 -
# Image saved to static/Results/detection.png
# static/Results/detection.png
# Results/detection.png
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:09] "GET /static/Results/detection.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:13] "GET /brain_detect HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:15] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:15] "GET /static/mainpage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:16] "GET /static/Images/usermain.jfif HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:17] "GET /retina HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:18] "GET /static/moleculeimage.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:28] "POST /feature/describe_image HTTP/1.1" 302 -
# Prediction saved to: static/Results/Segmantation_prediction.png
# result_path static/Results/Segmantation_prediction.png
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:29] "GET /static/Results/Segmantation_prediction.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:31] "GET /retina HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:33] "GET /MainPage HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Dec/2024 13:01:33] "GET /static/mainpage.css HTTP/1.1" 304 -
